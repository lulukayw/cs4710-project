# %% [markdown]
# # kNN Dominant Flavor Classifier — UVA Dining Data
#
# Trains a k-Nearest Neighbors classifier to predict a food item's **dominant flavor** — whichever of the 6 flavor scores (`sweet`, `salty`, `savory`, `spicy`, `sour`, `rich`) is highest.
#
# **Hyperparameters** tuned via grid search on the validation set:
# - `k` (n_neighbors) — number of nearest neighbors
# - `weights` — `uniform` (equal vote) vs `distance` (closer neighbors count more)
# - `metric` / `p` — distance function: Manhattan (p=1), Euclidean (p=2), Cubic Minkowski (p=3)
# - `scaler` — StandardScaler vs MinMaxScaler vs no scaling
#
# **Data split:** ~75% training / ~15% validation / ~10% testing (a day's worth of menu items)
#
# **Directory structure:**
# - `DATA_DIR` — where the individual categorized CSV files live (input, read-only)
# - `OUTPUT_DIR` — where the concatenated CSV and train/val/test splits are saved (output)

# %% [markdown]
# ## 1. Imports

# %%
import os
import re
import glob
import random
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from collections import Counter

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

sns.set_style("whitegrid")
# %matplotlib inline

# %% [markdown]
# ## 2. Configuration
#
# - `DATA_DIR` — folder with individual categorized CSV files (e.g., `3-30-2026-Breakfast_filled.csv`)
# - `OUTPUT_DIR` — folder where concatenated and split CSVs are saved

# %%
# Directory containing the individual categorized CSV files (input)
DATA_DIR = "./CategorizedData"

# Directory where concatenated CSV and train/val/test splits are saved (output)
OUTPUT_DIR = "./ondemand"

# Flavor profile feature columns (also used to derive the target label)
FEATURE_COLUMNS = ["sweet", "salty", "savory", "spicy", "sour", "rich"]

# Column that identifies individual items
ITEM_NAME_COLUMN = "name"

# Target label column (created automatically)
TARGET_COLUMN = "dominant_flavor"

# Random seed for reproducibility
RANDOM_SEED = 42

# Hyperparameter grid for grid search
PARAM_GRID = {
    "n_neighbors": [1, 3, 5, 7, 9, 11, 15, 19, 25],
    "weights":     ["uniform", "distance"],
    "metric":      ["minkowski"],
    "p":           [1, 2, 3],           # 1=Manhattan, 2=Euclidean, 3=cubic
    "scaler":      ["standard", "minmax", "none"],
}

RECOMMEND_DATE = "3-30-2026"   # must match a date in your CSV filenames exactly
RECOMMEND_MEAL = "Dinner"       # "Breakfast", "Lunch", or "Dinner"
TOP_N = 5                       # how many items to recommend

# Create output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Input directory:  {os.path.abspath(DATA_DIR)}")
print(f"Output directory: {os.path.abspath(OUTPUT_DIR)}")
# Out:
# Input directory:  /sfs/gpfs/tardis/home/rjb7gs/CategorizedData
# Output directory: /sfs/gpfs/tardis/home/rjb7gs/ondemand

# %% [markdown]
# ## 3. Data Loading
#
# Loads all individual CSV files from `DATA_DIR`, concatenates them, and saves the
# combined result to `OUTPUT_DIR/all_items_combined.csv`.

# %%
def parse_date_from_filename(filename: str) -> str:
    """Extract the date portion from filenames like '3-30-2026-Breakfast_filled.csv'."""
    base = os.path.basename(filename)
    match = re.match(r"(\d{1,2}-\d{1,2}-\d{4})", base)
    return match.group(1) if match else base


def parse_meal_from_filename(filename: str) -> str:
    """Extract 'Breakfast', 'Lunch', or 'Dinner' from the filename."""
    base = os.path.basename(filename)
    for meal in ["Breakfast", "Lunch", "Dinner"]:
        if meal in base:
            return meal
    return "Unknown"


def load_all_csvs(data_dir: str, output_dir: str) -> pd.DataFrame:
    """
    Load and concatenate all CSV files from data_dir.
    Saves the concatenated result to output_dir/all_items_combined.csv.
    """
    csv_pattern = os.path.join(data_dir, "*.csv")
    csv_files = sorted(glob.glob(csv_pattern))

    if not csv_files:
        raise FileNotFoundError(
            f"No CSV files found in '{data_dir}'. "
            f"Please place your categorized data CSVs in that folder."
        )

    frames = []
    for filepath in csv_files:
        df = pd.read_csv(filepath)
        df["source_file"] = os.path.basename(filepath)
        df["date"] = parse_date_from_filename(filepath)
        df["meal"] = parse_meal_from_filename(filepath)
        frames.append(df)
        print(f"  Loaded {os.path.basename(filepath):45s} — {len(df):>4d} rows")

    combined = pd.concat(frames, ignore_index=True)
    print(f"\n  Total rows loaded: {len(combined)}")

    # Save the concatenated dataframe to the output directory
    combined_path = os.path.join(output_dir, "all_items_combined.csv")
    combined.to_csv(combined_path, index=False)
    print(f"  Saved concatenated CSV → {combined_path}")

    return combined


df = load_all_csvs(DATA_DIR, OUTPUT_DIR)
df.head()
# check all categories so we know what to recommend
# print(df["category"].unique())
# Out:
#   Loaded 3-30-2026-Breakfast_filled.csv                —   38 rows
#   Loaded 3-30-2026-Dinner_filled.csv                   —   59 rows
#   Loaded 3-30-2026-Lunch_filled.csv                    —   59 rows
#   Loaded 3-31-2026-Breakfast_filled.csv                —   37 rows
#   Loaded 3-31-2026-Dinner_filled.csv                   —   68 rows
#   Loaded 3-31-2026-Lunch_filled.csv                    —   72 rows
#   Loaded 4-01-2026-Breakfast_filled.csv                —   37 rows
#   Loaded 4-01-2026-Dinner_filled.csv                   —   59 rows
#   Loaded 4-01-2026-Lunch_filled.csv                    —   58 rows
#   Loaded 4-02-2026-Breakfast_filled.csv                —   39 rows
#   Loaded 4-02-2026-Dinner_filled.csv                   —   60 rows
#   Loaded 4-02-2026-Lunch_filled.csv                    —   70 rows
#   Loaded 4-03-2026-Breakfast_filled.csv                —   39 rows
#   Loaded 4-03-2026-Dinner_filled.csv                   —   57 rows
#   Loaded 4-03-2026-Lunch_filled.csv                    —   70 rows
#   Loaded 4-04-2026-Breakfast_filled.csv                —   33 rows
#   Loaded 4-04-2026-Dinner_filled.csv                   —   68 rows
#   Loaded 4-04-2026-Lunch_filled.csv                    —   76 rows
#   Loaded 4-05-2026-Breakfast_filled.csv                —   37 rows
#   Loaded 4-05-2026-Dinner_filled.csv                   —   69 rows
#   Loaded 4-05-2026-Lunch_filled.csv                    —   77 rows
#   Loaded 4-06-2026-Breakfast_filled.csv                —   39 rows
#   Loaded 4-06-2026-Dinner_filled.csv                   —   56 rows
#   Loaded 4-06-2026-Lunch_filled.csv                    —   68 rows
#   Loaded 4-07-2026-Breakfast_filled.csv                —   39 rows
#   Loaded 4-07-2026-Dinner_filled.csv                   —   58 rows
#   Loaded 4-07-2026-Lunch_filled.csv                    —   70 rows
#   Loaded 4-08-2026-Breakfast_filled.csv                —   39 rows
#   Loaded 4-08-2026-Dinner_filled.csv                   —   64 rows
#   Loaded 4-08-2026-Lunch_filled.csv                    —   62 rows
#
#   Total rows loaded: 1677
#   Saved concatenated CSV → ./ondemand/all_items_combined.csv
#                           name                       category  \
# 0              Hard-Cooked Egg  Omelet/Quiche/Frittata/Strata
# 1          Scrambled Just® Egg  Omelet/Quiche/Frittata/Strata
# 2               Scrambled Eggs  Omelet/Quiche/Frittata/Strata
# 3  Egg, Sausage & Cheese Bagel                      Breakfast
# 4          Turkey Sausage Link                 Breakfast Meat
#
#                                          description  \
# 0  Perfectly hard-cooked egg, featuring a firm ye...
# 1    Scrambled Just® egg seasoned with salt & pepper
# 2         Eggs gently scrambled to fluffy perfection
# 3  Scrambled egg, breakfast sausage and American ...
# 4            Golden brown savory turkey sausage link
#
#                                          ingredients  diet_tags  allergens  \
# 0                                         Water, Egg        NaN        NaN
# 1  Plant Based Egg (Water, Mung Bean Protein, Exp...        NaN        NaN
# 2  Egg Blend (WHOLE EGGS, 19.0% WATER. CONTAINS 2...        NaN        NaN
# 3  Bagel, Egg Blend, Sausage Patty, American Chee...        NaN        NaN
# 4  Turkey Sausage (Turkey, Mechanically Separated...        NaN        NaN
#
#    sweet  salty  savory  spicy  sour  rich                     source_file  \
# 0    0.1    0.3     2.1    0.0   0.0   2.6  3-30-2026-Breakfast_filled.csv
# 1    0.1    0.8     1.8    0.1   0.0   1.7  3-30-2026-Breakfast_filled.csv
# 2    0.1    0.4     2.3    0.0   0.1   2.2  3-30-2026-Breakfast_filled.csv
# 3    0.7    2.8     3.8    0.2   0.1   3.2  3-30-2026-Breakfast_filled.csv
# 4    0.3    2.2     3.4    0.4   0.1   2.4  3-30-2026-Breakfast_filled.csv
#
#         date       meal
# 0  3-30-2026  Breakfast
# 1  3-30-2026  Breakfast
# 2  3-30-2026  Breakfast
# 3  3-30-2026  Breakfast
# 4  3-30-2026  Breakfast

# %% [markdown]
# ## 4. Data Cleaning & Dominant Flavor Labels
#
# For each item, the **dominant flavor** is whichever of the 6 flavor scores is
# highest. Items with all-zero scores are labeled `neutral`.

# %%
def clean_and_label(df: pd.DataFrame) -> pd.DataFrame:
    """Clean data and create the dominant-flavor target label."""
    df = df.copy()

    # Drop rows with missing flavor values
    before = len(df)
    df = df.dropna(subset=FEATURE_COLUMNS)
    dropped = before - len(df)
    if dropped > 0:
        print(f"  Dropped {dropped} rows with missing flavor values.")

    # Derive the dominant flavor label
    flavor_values = df[FEATURE_COLUMNS]
    df[TARGET_COLUMN] = flavor_values.idxmax(axis=1)

    # Handle all-zero edge case
    all_zero_mask = flavor_values.sum(axis=1) == 0
    if all_zero_mask.any():
        df.loc[all_zero_mask, TARGET_COLUMN] = "neutral"
        print(f"  Note: {all_zero_mask.sum()} items with all-zero scores → 'neutral'.")

    return df


df = clean_and_label(df)
print(f"\nTotal usable items: {len(df)}")
df[[ITEM_NAME_COLUMN] + FEATURE_COLUMNS + [TARGET_COLUMN]].head(10)
# Out:
# Total usable items: 1677
#                           name  sweet  salty  savory  spicy  sour  rich  \
# 0              Hard-Cooked Egg    0.1    0.3     2.1    0.0   0.0   2.6
# 1          Scrambled Just® Egg    0.1    0.8     1.8    0.1   0.0   1.7
# 2               Scrambled Eggs    0.1    0.4     2.3    0.0   0.1   2.2
# 3  Egg, Sausage & Cheese Bagel    0.7    2.8     3.8    0.2   0.1   3.2
# 4          Turkey Sausage Link    0.3    2.2     3.4    0.4   0.1   2.4
# 5           Pork Sausage Links    0.2    2.1     3.7    0.2   0.1   3.0
# 6          Hash Brown Potatoes    0.2    1.7     2.4    0.2   0.1   1.8
# 7             O'Brien Potatoes    0.4    1.7     2.5    0.2   0.2   1.7
# 8                      Pancake    2.2    0.5     0.3    0.0   0.1   0.8
# 9          Buttermilk Pancakes    2.3    0.6     0.4    0.0   0.4   1.1
#
#   dominant_flavor
# 0            rich
# 1          savory
# 2          savory
# 3          savory
# 4          savory
# 5          savory
# 6          savory
# 7          savory
# 8           sweet
# 9           sweet

# %% [markdown]
# ### Dominant Flavor Distribution

# %%
label_counts = df[TARGET_COLUMN].value_counts()

fig, ax = plt.subplots(figsize=(8, 4))
colors = {"sweet": "#FF9999", "salty": "#66B2FF", "savory": "#99CC99",
          "spicy": "#FF6633", "sour": "#FFCC00", "rich": "#CC99FF", "neutral": "#CCCCCC"}
bar_colors = [colors.get(l, "#888888") for l in label_counts.index]

label_counts.plot(kind="barh", ax=ax, color=bar_colors, edgecolor="black", linewidth=0.5)
ax.set_xlabel("Number of Items")
ax.set_title("Dominant Flavor Distribution")
for i, (count, label) in enumerate(zip(label_counts.values, label_counts.index)):
    ax.text(count + 1, i, f"{count}  ({count/len(df)*100:.1f}%)", va="center", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Train / Validation / Test Split
#
# The **test set** simulates a day's worth of dining — items are sampled
# proportionally by meal (breakfast, lunch, dinner) from one date (~10% of data).
#
# The split CSVs are saved to `OUTPUT_DIR`:
# - `train_split.csv`
# - `validation_split.csv`
# - `test_split.csv`

# %%
def split_data(df, train_ratio=0.75, val_ratio=0.15, test_ratio=0.10, seed=42):
    """Split data into train/val/test. Test set = one day's menu sample."""
    rng = random.Random(seed)
    np.random.seed(seed)

    n_total = len(df)
    target_test_size = int(round(n_total * test_ratio))

    dates = df["date"].unique().tolist()
    day_sizes = {d: len(df[df["date"] == d]) for d in dates}

    print("Available dates:")
    for d in sorted(dates):
        meals = df[df["date"] == d]["meal"].unique()
        print(f"  {d}: {day_sizes[d]} items  (meals: {', '.join(sorted(meals))})")

    best_day = min(dates, key=lambda d: abs(day_sizes[d] - target_test_size))
    day_df = df[df["date"] == best_day]

    if day_sizes[best_day] <= target_test_size * 2:
        df_test = day_df.reset_index(drop=True)
        print(f"\nTest day: {best_day} ({day_sizes[best_day]} items, used in full)")
    else:
        print(f"\nDay {best_day} has {day_sizes[best_day]} items "
              f"(target ~{target_test_size}). Sampling by meal...")
        test_parts = []
        meal_counts = day_df["meal"].value_counts(normalize=True)
        for meal in day_df["meal"].unique():
            meal_df = day_df[day_df["meal"] == meal]
            n_from_meal = max(1, int(round(meal_counts[meal] * target_test_size)))
            n_from_meal = min(n_from_meal, len(meal_df))
            test_parts.append(meal_df.sample(n=n_from_meal, random_state=seed))
        df_test = pd.concat(test_parts).reset_index(drop=True)
        if len(df_test) > target_test_size:
            df_test = df_test.sample(n=target_test_size, random_state=seed).reset_index(drop=True)
        print(f"Sampled {len(df_test)} items from {best_day}")

    # Exclude test items from remaining data
    test_keys = set(
        zip(df_test[ITEM_NAME_COLUMN], df_test["date"], df_test["meal"],
            df_test["sweet"], df_test["salty"])
    )
    remaining_mask = ~df.apply(
        lambda r: (r[ITEM_NAME_COLUMN], r["date"], r["meal"],
                   r["sweet"], r["salty"]) in test_keys,
        axis=1,
    )
    remaining = df[remaining_mask].sample(frac=1, random_state=seed).reset_index(drop=True)

    effective_train_ratio = train_ratio / (train_ratio + val_ratio)
    n_train = int(round(len(remaining) * effective_train_ratio))

    df_train = remaining.iloc[:n_train].reset_index(drop=True)
    df_val = remaining.iloc[n_train:].reset_index(drop=True)

    return df_train, df_val, df_test


df_train, df_val, df_test = split_data(df, 0.75, 0.15, 0.10, RANDOM_SEED)

print(f"\nTraining set:    {len(df_train):>4d} items  ({len(df_train)/len(df)*100:.1f}%)")
print(f"Validation set:  {len(df_val):>4d} items  ({len(df_val)/len(df)*100:.1f}%)")
print(f"Test set (day):  {len(df_test):>4d} items  ({len(df_test)/len(df)*100:.1f}%)")

for label, subset in [("Train", df_train), ("Val", df_val), ("Test", df_test)]:
    counts = Counter(subset[TARGET_COLUMN].values)
    summary = ", ".join(f"{k}: {v}" for k, v in counts.most_common())
    print(f"  {label:5s} — {summary}")

# Save split CSVs to output directory
df_train.to_csv(os.path.join(OUTPUT_DIR, "train_split.csv"), index=False)
df_val.to_csv(os.path.join(OUTPUT_DIR, "validation_split.csv"), index=False)
df_test.to_csv(os.path.join(OUTPUT_DIR, "test_split.csv"), index=False)
print(f"\nSaved split CSVs to '{OUTPUT_DIR}/':")
print(f"  train_split.csv       ({len(df_train)} items)")
print(f"  validation_split.csv  ({len(df_val)} items)")
print(f"  test_split.csv        ({len(df_test)} items)")
# Out:
# Available dates:
#   3-30-2026: 156 items  (meals: Breakfast, Dinner, Lunch)
#   3-31-2026: 177 items  (meals: Breakfast, Dinner, Lunch)
#   4-01-2026: 154 items  (meals: Breakfast, Dinner, Lunch)
#   4-02-2026: 169 items  (meals: Breakfast, Dinner, Lunch)
#   4-03-2026: 166 items  (meals: Breakfast, Dinner, Lunch)
#   4-04-2026: 177 items  (meals: Breakfast, Dinner, Lunch)
#   4-05-2026: 183 items  (meals: Breakfast, Dinner, Lunch)
#   4-06-2026: 163 items  (meals: Breakfast, Dinner, Lunch)
#   4-07-2026: 167 items  (meals: Breakfast, Dinner, Lunch)
#   4-08-2026: 165 items  (meals: Breakfast, Dinner, Lunch)
#
# Test day: 4-02-2026 (169 items, used in full)
#
# Training set:    1257 items  (75.0%)
# Validation set:   251 items  (15.0%)
# Test set (day):   169 items  (10.1%)
#   Train — savory: 558, rich: 427, salty: 153, sweet: 79, spicy: 25, sour: 15
#   Val   — savory: 114, rich: 82, salty: 32, sweet: 16, spicy: 6, sour: 1
#   Test  — savory: 68, rich: 66, salty: 18, sweet: 10, spicy: 4, sour: 3
#
# Saved split CSVs to './ondemand/':
#   train_split.csv       (1257 items)
#   validation_split.csv  (251 items)
#   test_split.csv        (169 items)

# %% [markdown]
# ## 6. Feature Extraction

# %%
X_train_raw = df_train[FEATURE_COLUMNS].values.astype(float)
y_train     = df_train[TARGET_COLUMN].values

X_val_raw   = df_val[FEATURE_COLUMNS].values.astype(float)
y_val       = df_val[TARGET_COLUMN].values

X_test_raw  = df_test[FEATURE_COLUMNS].values.astype(float)
y_test      = df_test[TARGET_COLUMN].values

print(f"X_train shape: {X_train_raw.shape}")
print(f"X_val shape:   {X_val_raw.shape}")
print(f"X_test shape:  {X_test_raw.shape}")
print(f"Classes:       {sorted(set(y_train))}")
# Out:
# X_train shape: (1257, 6)
# X_val shape:   (251, 6)
# X_test shape:  (169, 6)
# Classes:       ['rich', 'salty', 'savory', 'sour', 'spicy', 'sweet']

# %% [markdown]
# ## 7. Scaling Helpers

# %%
def get_scaler(scaler_name: str):
    """Return a scaler instance (or None) based on name."""
    if scaler_name == "standard":
        return StandardScaler()
    elif scaler_name == "minmax":
        return MinMaxScaler()
    return None


def scale_features(X_train, X_val, X_test, scaler_name: str):
    """Fit scaler on training data and transform all splits."""
    scaler = get_scaler(scaler_name)
    if scaler is not None:
        X_train_s = scaler.fit_transform(X_train)
        X_val_s   = scaler.transform(X_val)
        X_test_s  = scaler.transform(X_test)
    else:
        X_train_s = X_train.copy()
        X_val_s   = X_val.copy()
        X_test_s  = X_test.copy()
    return X_train_s, X_val_s, X_test_s, scaler

# %% [markdown]
# ## 8. Hyperparameter Grid Search
#
# Exhaustively evaluates all combinations of `k`, `weights`, `p` (distance metric),
# and `scaler` on the validation set.

# %%
def grid_search(X_train_raw, y_train, X_val_raw, y_val, X_test_raw, param_grid):
    """Exhaustive grid search. Returns best params, model, scaled data, and results."""
    keys = list(param_grid.keys())
    combos = list(itertools.product(*[param_grid[k] for k in keys]))

    print(f"Evaluating {len(combos)} hyperparameter combinations...")

    results = []
    best_acc = -1
    best_entry = None
    best_scaler = None

    for combo in combos:
        params = dict(zip(keys, combo))

        X_tr, X_va, X_te, scaler = scale_features(
            X_train_raw, X_val_raw, X_test_raw, params["scaler"]
        )

        model = KNeighborsClassifier(
            n_neighbors=params["n_neighbors"],
            weights=params["weights"],
            metric=params["metric"],
            p=params["p"],
        )
        model.fit(X_tr, y_train)
        val_acc = accuracy_score(y_val, model.predict(X_va))

        entry = {**params, "val_accuracy": val_acc}
        results.append(entry)

        if val_acc > best_acc:
            best_acc = val_acc
            best_entry = entry
            best_model = model
            best_scaler = scaler
            best_X_train = X_tr
            best_X_val = X_va
            best_X_test = X_te

    results_df = pd.DataFrame(results).sort_values("val_accuracy", ascending=False)
    return best_entry, best_model, best_X_train, best_X_val, best_X_test, best_scaler, results_df


best_params, best_model, X_train, X_val, X_test, best_scaler, results_df = grid_search(
    X_train_raw, y_train, X_val_raw, y_val, X_test_raw, PARAM_GRID
)

print("\nTop 15 hyperparameter combinations:")
results_df.head(15)
# Out:
# Evaluating 162 hyperparameter combinations...
#
# Top 15 hyperparameter combinations:
#     n_neighbors   weights     metric  p    scaler  val_accuracy
# 6             1   uniform  minkowski  3  standard      0.972112
# 3             1   uniform  minkowski  2  standard      0.972112
# 15            1  distance  minkowski  3  standard      0.972112
# 17            1  distance  minkowski  3      none      0.972112
# 8             1   uniform  minkowski  3      none      0.972112
# 12            1  distance  minkowski  2  standard      0.972112
# 35            3  distance  minkowski  3      none      0.972112
# 32            3  distance  minkowski  2      none      0.968127
# 7             1   uniform  minkowski  3    minmax      0.968127
# 16            1  distance  minkowski  3    minmax      0.968127
# 14            1  distance  minkowski  2      none      0.968127
# 31            3  distance  minkowski  2    minmax      0.968127
# 5             1   uniform  minkowski  2      none      0.968127
# 13            1  distance  minkowski  2    minmax      0.968127
# 26            3   uniform  minkowski  3      none      0.968127

# %% [markdown]
# ### Best Hyperparameters

# %%
p_names = {1: "Manhattan", 2: "Euclidean", 3: "Cubic Minkowski"}

p_val = best_params['p']
dist_name = p_names.get(p_val, f"Minkowski p={p_val}")

print(f"k (n_neighbors) = {best_params['n_neighbors']}")
print(f"weights         = {best_params['weights']}")
print(f"distance        = {dist_name} (p={p_val})")
print(f"scaler          = {best_params['scaler']}")
print(f"val accuracy    = {best_params['val_accuracy']:.4f}")
# Out:
# k (n_neighbors) = 1
# weights         = uniform
# distance        = Euclidean (p=2)
# scaler          = standard
# val accuracy    = 0.9721

# %% [markdown]
# ### Validation Accuracy vs k

# %%
# Filter to the best weight/p/scaler combo and plot accuracy vs k
best_w = best_params["weights"]
best_p = best_params["p"]
best_s = best_params["scaler"]

subset = results_df[
    (results_df["weights"] == best_w) &
    (results_df["p"] == best_p) &
    (results_df["scaler"] == best_s)
].sort_values("n_neighbors")

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(subset["n_neighbors"], subset["val_accuracy"], "o-", color="#5B4ABF", linewidth=2, markersize=8)
ax.set_xlabel("k (n_neighbors)")
ax.set_ylabel("Validation Accuracy")
ax.set_title(f"Validation Accuracy vs k\n(weights={best_w}, p={best_p}, scaler={best_s})")
ax.set_xticks(subset["n_neighbors"])
ax.set_ylim(0, 1.05)
ax.axhline(y=best_params["val_accuracy"], color="red", linestyle="--", alpha=0.5, label=f"Best = {best_params['val_accuracy']:.3f}")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Model Evaluation

# %%
def evaluate_model(model, X, y, set_name="Test"):
    """Print classification report and return accuracy."""
    y_pred = model.predict(X)
    acc = accuracy_score(y, y_pred)

    print(f"\n{'='*60}")
    print(f"  {set_name} Set — Accuracy: {acc:.4f} ({acc*100:.1f}%)")
    print(f"{'='*60}")

    labels = sorted(set(y) | set(y_pred))
    print(classification_report(y, y_pred, labels=labels, zero_division=0))

    return acc, y_pred

# %% [markdown]
# ### Training Set

# %%
train_acc, _ = evaluate_model(best_model, X_train, y_train, "Training")
# Out:
# ============================================================
#   Training Set — Accuracy: 1.0000 (100.0%)
# ============================================================
#               precision    recall  f1-score   support
#
#         rich       1.00      1.00      1.00       427
#        salty       1.00      1.00      1.00       153
#       savory       1.00      1.00      1.00       558
#         sour       1.00      1.00      1.00        15
#        spicy       1.00      1.00      1.00        25
#        sweet       1.00      1.00      1.00        79
#
#     accuracy                           1.00      1257
#    macro avg       1.00      1.00      1.00      1257
# weighted avg       1.00      1.00      1.00      1257

# %% [markdown]
# ### Validation Set

# %%
val_acc, _ = evaluate_model(best_model, X_val, y_val, "Validation")
# Out:
# ============================================================
#   Validation Set — Accuracy: 0.9721 (97.2%)
# ============================================================
#               precision    recall  f1-score   support
#
#         rich       0.96      0.96      0.96        82
#        salty       0.97      0.94      0.95        32
#       savory       0.97      0.99      0.98       114
#         sour       0.00      0.00      0.00         1
#        spicy       1.00      1.00      1.00         6
#        sweet       1.00      1.00      1.00        16
#
#     accuracy                           0.97       251
#    macro avg       0.82      0.82      0.82       251
# weighted avg       0.97      0.97      0.97       251

# %% [markdown]
# ### Test Set (Day's Menu)

# %%
test_acc, y_test_pred = evaluate_model(best_model, X_test, y_test, "Test (Day's Menu)")
# Out:
# ============================================================
#   Test (Day's Menu) Set — Accuracy: 0.9704 (97.0%)
# ============================================================
#               precision    recall  f1-score   support
#
#         rich       0.98      0.95      0.97        66
#        salty       0.94      0.94      0.94        18
#       savory       0.97      0.99      0.98        68
#         sour       1.00      1.00      1.00         3
#        spicy       1.00      1.00      1.00         4
#        sweet       0.91      1.00      0.95        10
#
#     accuracy                           0.97       169
#    macro avg       0.97      0.98      0.97       169
# weighted avg       0.97      0.97      0.97       169

# %% [markdown]
# ### Confusion Matrix — Test Set

# %%
labels = sorted(set(y_test) | set(y_test_pred))
cm = confusion_matrix(y_test, y_test_pred, labels=labels)

fig, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels,
            yticklabels=labels, ax=ax, linewidths=0.5, cbar_kws={"shrink": 0.8})
ax.set_xlabel("Predicted Flavor")
ax.set_ylabel("True Flavor")
ax.set_title(f"Test Set Confusion Matrix — Accuracy: {test_acc:.1%}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Test Day — Item-by-Item Predictions
#
# Each row shows the item name, its true dominant flavor, the model's prediction,
# and all 6 flavor scores for context.

# %%
# Build a detailed results dataframe
results_detail = df_test[[ITEM_NAME_COLUMN, "meal", TARGET_COLUMN] + FEATURE_COLUMNS].copy()
results_detail["predicted"] = y_test_pred
results_detail["correct"] = results_detail[TARGET_COLUMN] == results_detail["predicted"]

# Sort by meal order
meal_order = {"Breakfast": 0, "Lunch": 1, "Dinner": 2, "Unknown": 3}
results_detail["_sort"] = results_detail["meal"].map(meal_order)
results_detail = results_detail.sort_values("_sort").drop(columns="_sort")

# Display
correct_count = results_detail["correct"].sum()
total = len(results_detail)

for meal in ["Breakfast", "Lunch", "Dinner"]:
    meal_items = results_detail[results_detail["meal"] == meal]
    if meal_items.empty:
        continue
    print(f"\n--- {meal} ---")
    for _, row in meal_items.iterrows():
        mark = "✓" if row["correct"] else "✗"
        scores = " ".join(f"{c[:3]}={row[c]:.1f}" for c in FEATURE_COLUMNS)
        print(f"  {mark}  {str(row[ITEM_NAME_COLUMN]):40s}  "
              f"true={str(row[TARGET_COLUMN]):8s}  pred={str(row['predicted']):8s}  [{scores}]")

print(f"\nDay accuracy: {correct_count}/{total} ({correct_count/total*100:.1f}%)")
# Out:
# --- Breakfast ---
#   ✓  Smoked  Maple Sausage                     true=salty     pred=salty     [swe=3.6 sal=3.8 sav=3.2 spi=1.2 sou=0.8 ric=2.5]
#   ✓  Hard-Cooked Egg                           true=rich      pred=rich      [swe=1.3 sal=2.5 sav=4.8 spi=1.4 sou=0.3 ric=5.0]
#   ✓  Scrambled Just® Egg                       true=savory    pred=savory    [swe=1.9 sal=2.6 sav=3.9 spi=2.8 sou=1.5 ric=1.8]
#   ✓  Scrambled Eggs                            true=savory    pred=savory    [swe=1.3 sal=4.1 sav=4.4 spi=1.0 sou=0.9 ric=3.0]
#   ✓  Egg White Ham English Muffin              true=salty     pred=salty     [swe=2.7 sal=5.0 sav=4.0 spi=1.1 sou=0.1 ric=1.5]
#   ✓  Turkey Sausage Patty                      true=salty     pred=salty     [swe=2.9 sal=4.5 sav=2.8 spi=0.2 sou=0.4 ric=2.4]
#   ✓  O'Brien Potatoes                          true=rich      pred=rich      [swe=0.8 sal=4.1 sav=4.4 spi=2.4 sou=1.3 ric=5.0]
#   ✓  Crispy Tater Tots                         true=rich      pred=rich      [swe=0.6 sal=3.4 sav=2.4 spi=0.7 sou=1.1 ric=3.8]
#   ✓  Pancake                                   true=sweet     pred=sweet     [swe=5.0 sal=4.7 sav=4.7 spi=1.4 sou=1.5 ric=3.0]
#   ✓  French Toast                              true=savory    pred=savory    [swe=3.0 sal=3.5 sav=3.8 spi=0.1 sou=0.7 ric=3.5]
#   ✓  Southern Biscuit                          true=rich      pred=rich      [swe=2.2 sal=3.4 sav=2.7 spi=1.3 sou=0.6 ric=4.0]
#   ✓  Chocolate Chip Scone                      true=sweet     pred=sweet     [swe=5.0 sal=3.4 sav=2.4 spi=0.5 sou=0.9 ric=4.6]
#   ✓  Apple-Topped Cinnamon Roll                true=savory    pred=savory    [swe=0.7 sal=2.9 sav=3.7 spi=1.1 sou=1.4 ric=1.2]
#   ✓  Old Fashioned Oatmeal                     true=savory    pred=savory    [swe=0.4 sal=1.7 sav=2.7 spi=1.4 sou=0.6 ric=2.1]
#   ✓  Overnight Oats                            true=rich      pred=rich      [swe=2.4 sal=3.6 sav=3.6 spi=0.9 sou=3.3 ric=4.2]
#   ✓  Berry and Veggie Smoothie                 true=savory    pred=savory    [swe=0.2 sal=2.2 sav=3.8 spi=0.6 sou=0.8 ric=2.0]
#   ✓  Lemon Arugula Mushroom Crepe              true=rich      pred=rich      [swe=2.8 sal=4.0 sav=3.8 spi=0.5 sou=2.9 ric=5.0]
#   ✓  Smoked Chicken Apple Sausage              true=salty     pred=salty     [swe=3.6 sal=5.0 sav=5.0 spi=0.5 sou=0.4 ric=3.1]
#   ✓  Egg Whites                                true=savory    pred=savory    [swe=0.5 sal=2.7 sav=3.9 spi=0.9 sou=1.0 ric=1.6]
#   ✓  Shredded Cheddar Cheese                   true=rich      pred=rich      [swe=1.3 sal=2.3 sav=4.0 spi=1.2 sou=0.4 ric=5.0]
#   ✓  Eggs                                      true=savory    pred=savory    [swe=0.5 sal=1.3 sav=3.0 spi=1.5 sou=0.1 ric=2.8]
#   ✓  Cottage Cheese                            true=rich      pred=rich      [swe=0.4 sal=2.4 sav=2.6 spi=0.2 sou=0.6 ric=3.9]
#   ✓  Nonfat Strawberry Yogurt                  true=sour      pred=sour      [swe=0.6 sal=2.8 sav=2.4 spi=0.5 sou=4.5 ric=3.1]
#   ✓  Nonfat Vanilla Yogurt                     true=rich      pred=rich      [swe=1.3 sal=1.6 sav=2.2 spi=1.0 sou=3.3 ric=4.3]
#   ✓  Chia Quinoa Crunch                        true=sweet     pred=sweet     [swe=2.6 sal=1.5 sav=2.2 spi=0.0 sou=0.4 ric=1.7]
#   ✓  Nonfat Greek Yogurt                       true=savory    pred=savory    [swe=1.3 sal=1.8 sav=3.7 spi=1.0 sou=3.5 ric=2.0]
#   ✓  Toasted Sunflower Seeds                   true=rich      pred=rich      [swe=0.3 sal=2.5 sav=2.3 spi=0.8 sou=0.4 ric=3.2]
#   ✓  Chopped Fresh Spinach                     true=savory    pred=savory    [swe=0.1 sal=2.0 sav=2.6 spi=1.4 sou=0.8 ric=1.4]
#   ✓  Honey Granola                             true=sweet     pred=sweet     [swe=3.1 sal=1.6 sav=2.9 spi=1.0 sou=0.8 ric=2.7]
#   ✓  Toasted Coconut                           true=savory    pred=savory    [swe=0.7 sal=2.0 sav=2.9 spi=1.3 sou=1.0 ric=1.2]
#   ✓  Fresh Fruit Salad                         true=sweet     pred=sweet     [swe=3.6 sal=2.0 sav=2.7 spi=1.2 sou=1.4 ric=1.0]
#   ✓  Sliced Mushrooms                          true=savory    pred=savory    [swe=1.3 sal=2.9 sav=3.3 spi=1.0 sou=1.2 ric=2.4]
#   ✓  Diced Onions                              true=savory    pred=savory    [swe=0.6 sal=1.9 sav=4.3 spi=1.0 sou=1.5 ric=2.6]
#   ✓  Sliced Mixed Bell Peppers                 true=spicy     pred=spicy     [swe=0.3 sal=2.4 sav=2.7 spi=3.8 sou=1.4 ric=1.7]
#   ✓  Diced Tomatoes                            true=rich      pred=rich      [swe=0.5 sal=2.4 sav=2.2 spi=0.5 sou=1.0 ric=3.1]
#   ✓  Toasted Pumpkin Seeds                     true=savory    pred=savory    [swe=0.4 sal=2.2 sav=2.4 spi=0.8 sou=1.0 ric=1.5]
#   ✓  Dried Cranberries                         true=sweet     pred=sweet     [swe=3.0 sal=2.7 sav=2.7 spi=1.0 sou=0.2 ric=2.3]
#   ✓  Fresh Fruit Salad                         true=sweet     pred=sweet     [swe=3.6 sal=2.0 sav=2.7 spi=1.2 sou=1.4 ric=1.0]
#   ✓  GRAVY, SAUSAGE, MIX wr                    true=salty     pred=salty     [swe=1.9 sal=4.9 sav=4.2 spi=3.6 sou=2.5 ric=2.8]
#
# --- Lunch ---
#   ✗  Grilled Indian-Spiced Chicken             true=savory    pred=rich      [swe=0.1 sal=1.2 sav=4.0 spi=1.1 sou=0.8 ric=3.7]
#   ✓  Onion & Pepper Pizza                      true=rich      pred=rich      [swe=2.2 sal=3.9 sav=3.9 spi=3.5 sou=0.2 ric=4.4]
#   ✓  Char-Grilled Turkey Burger                true=savory    pred=savory    [swe=0.3 sal=1.2 sav=3.6 spi=0.3 sou=1.1 ric=1.5]
#   ✓  Grilled Black Bean Burger                 true=savory    pred=savory    [swe=0.1 sal=1.1 sav=3.7 spi=1.2 sou=1.2 ric=2.0]
#   ✓  OH Pepperoni Pizza                        true=rich      pred=rich      [swe=3.8 sal=4.3 sav=3.6 spi=3.1 sou=0.9 ric=5.0]
#   ✓  Baja Turkey Wrap                          true=savory    pred=savory    [swe=3.3 sal=2.7 sav=4.8 spi=2.7 sou=2.2 ric=4.2]
#   ✓  OH Classic Cheese Pizza                   true=rich      pred=rich      [swe=3.0 sal=3.3 sav=4.0 spi=0.4 sou=1.5 ric=5.0]
#   ✓  Vegan Bar Sesame Soy Tofu                 true=savory    pred=savory    [swe=2.4 sal=4.4 sav=4.9 spi=2.7 sou=0.6 ric=3.6]
#   ✓  Ravioli Primavera                         true=rich      pred=rich      [swe=1.3 sal=3.9 sav=2.5 spi=3.2 sou=0.6 ric=5.0]
#   ✓  Roasted Mushrooms                         true=savory    pred=savory    [swe=0.1 sal=2.6 sav=4.5 spi=3.3 sou=0.1 ric=3.6]
#   ✓  Roasted Cauliflower Shawarma              true=savory    pred=savory    [swe=1.3 sal=3.6 sav=5.0 spi=2.4 sou=1.0 ric=3.7]
#   ✓  Roasted Shawarma Chickpeas                true=savory    pred=savory    [swe=1.2 sal=3.6 sav=5.0 spi=1.7 sou=1.2 ric=4.3]
#   ✓  Meze Tomato Cucumber Salad                true=savory    pred=savory    [swe=1.0 sal=3.9 sav=4.7 spi=3.4 sou=3.0 ric=2.5]
#   ✓  Caprese Salad                             true=rich      pred=rich      [swe=1.1 sal=3.8 sav=3.5 spi=3.1 sou=2.6 ric=5.0]
#   ✓  Green Beans Gremolada                     true=rich      pred=rich      [swe=1.0 sal=4.0 sav=3.1 spi=2.9 sou=3.1 ric=4.2]
#   ✓  Roasted Brussels Sprouts & Carrots with Balsamic Glaze  true=savory    pred=savory    [swe=3.0 sal=3.1 sav=5.0 spi=1.1 sou=0.4 ric=5.0]
#   ✓  Roasted Cauliflower                       true=salty     pred=salty     [swe=1.3 sal=3.7 sav=3.3 spi=3.6 sou=0.7 ric=3.6]
#   ✓  Yellow Basmati Rice                       true=salty     pred=salty     [swe=0.4 sal=4.2 sav=3.6 spi=0.7 sou=0.0 ric=3.3]
#   ✓  Crispy Seasoned French Fries              true=rich      pred=rich      [swe=1.0 sal=2.5 sav=3.3 spi=1.4 sou=0.4 ric=3.4]
#   ✓  Farro                                     true=salty     pred=salty     [swe=1.4 sal=3.0 sav=2.2 spi=0.9 sou=0.3 ric=3.0]
#   ✓  Jasmine Rice                              true=rich      pred=rich      [swe=0.2 sal=2.6 sav=2.3 spi=1.3 sou=0.7 ric=3.3]
#   ✓  Cream Cheese Marbled Brownie              true=sweet     pred=sweet     [swe=5.0 sal=1.4 sav=3.8 spi=0.3 sou=1.4 ric=2.8]
#   ✓  Cavalier Club                             true=salty     pred=salty     [swe=2.9 sal=5.0 sav=4.7 spi=3.8 sou=2.7 ric=3.2]
#   ✓  Corner Chicken Salad Croissant            true=rich      pred=rich      [swe=0.0 sal=2.8 sav=4.0 spi=2.7 sou=3.4 ric=4.6]
#   ✓  Boardwalk Tofu Wrap                       true=savory    pred=savory    [swe=0.9 sal=4.3 sav=5.0 spi=2.1 sou=3.5 ric=2.8]
#   ✓  Crispy Chicken Nuggets                    true=rich      pred=rich      [swe=2.4 sal=3.1 sav=3.9 spi=0.1 sou=0.6 ric=5.0]
#   ✓  Grilled Italian Vinaigrette Chicken Thigh  true=rich      pred=rich      [swe=2.6 sal=3.2 sav=3.2 spi=2.3 sou=2.9 ric=4.6]
#   ✓  Roasted Eggplant Mezze                    true=savory    pred=savory    [swe=2.1 sal=3.6 sav=5.0 spi=3.2 sou=2.7 ric=3.7]
#   ✓  Sweet & Sour Plant-Based Chicken Stir Fry  true=savory    pred=savory    [swe=3.7 sal=4.4 sav=4.8 spi=3.0 sou=3.3 ric=3.5]
#   ✓  Sliced Tomatoes                           true=savory    pred=savory    [swe=0.9 sal=1.5 sav=2.1 spi=1.1 sou=0.3 ric=2.1]
#   ✓  Green Leaf Lettuce                        true=salty     pred=salty     [swe=0.4 sal=2.9 sav=2.9 spi=0.7 sou=0.2 ric=1.9]
#   ✓  Spring Salad Mix                          true=salty     pred=salty     [swe=0.8 sal=2.6 sav=2.2 spi=1.4 sou=1.4 ric=1.4]
#   ✓  Shredded Carrots                          true=savory    pred=savory    [swe=0.6 sal=1.1 sav=2.5 spi=1.3 sou=1.3 ric=1.3]
#   ✓  Sliced Red Bell Peppers                   true=savory    pred=savory    [swe=0.1 sal=1.8 sav=3.3 spi=2.1 sou=1.2 ric=1.8]
#   ✓  Roasted Corn                              true=savory    pred=savory    [swe=0.1 sal=3.6 sav=4.0 spi=3.1 sou=0.7 ric=1.5]
#   ✓  Cucumbers                                 true=savory    pred=savory    [swe=0.6 sal=1.2 sav=3.0 spi=0.3 sou=0.3 ric=2.4]
#   ✓  Sliced Green Bell Peppers                 true=spicy     pred=spicy     [swe=0.3 sal=1.9 sav=3.2 spi=3.7 sou=1.0 ric=1.1]
#   ✓  Grape Tomatoes                            true=savory    pred=savory    [swe=0.6 sal=2.1 sav=3.9 spi=0.1 sou=0.0 ric=3.1]
#   ✓  Romaine Lettuce                           true=savory    pred=savory    [swe=0.7 sal=1.9 sav=3.5 spi=0.6 sou=0.8 ric=2.9]
#   ✓  Feta Cheese Crumbles                      true=rich      pred=rich      [swe=0.2 sal=1.5 sav=3.0 spi=0.5 sou=0.7 ric=5.0]
#   ✓  Sliced Red Onions                         true=rich      pred=rich      [swe=1.1 sal=1.3 sav=3.4 spi=0.8 sou=1.1 ric=3.5]
#   ✓  Meze Tzatziki Sauce                       true=savory    pred=savory    [swe=0.5 sal=3.5 sav=5.0 spi=3.0 sou=5.0 ric=5.0]
#   ✓  Smoky Chipotle Mayo                       true=savory    pred=savory    [swe=3.0 sal=2.4 sav=5.0 spi=2.6 sou=2.5 ric=2.5]
#   ✓  Baba Ghanoush                             true=savory    pred=savory    [swe=1.4 sal=4.1 sav=5.0 spi=3.2 sou=4.0 ric=3.3]
#   ✓  Croutons                                  true=savory    pred=savory    [swe=0.7 sal=1.1 sav=2.1 spi=0.7 sou=1.0 ric=1.2]
#   ✓  Goldfish® Crackers                        true=savory    pred=savory    [swe=0.9 sal=2.8 sav=3.5 spi=0.3 sou=0.8 ric=3.0]
#   ✓  Chopped Fresh Spinach                     true=savory    pred=savory    [swe=0.1 sal=2.0 sav=2.6 spi=1.4 sou=0.8 ric=1.4]
#   ✓  O'Hill Smash Burger*                      true=rich      pred=rich      [swe=2.6 sal=4.6 sav=4.2 spi=3.3 sou=1.2 ric=5.0]
#   ✓  Basil Pesto                               true=rich      pred=rich      [swe=1.1 sal=2.4 sav=2.4 spi=1.0 sou=0.1 ric=3.2]
#   ✓  Fat-Free French Dressing                  true=rich      pred=rich      [swe=0.6 sal=2.2 sav=2.2 spi=0.1 sou=1.2 ric=2.4]
#   ✓  Burger Sauce                              true=rich      pred=rich      [swe=3.6 sal=1.6 sav=2.1 spi=3.2 sou=2.8 ric=4.4]
#   ✓  Dijon Mustard                             true=savory    pred=savory    [swe=0.4 sal=2.9 sav=4.0 spi=0.9 sou=1.0 ric=3.3]
#   ✓  Honey Mustard Dressing                    true=sweet     pred=sweet     [swe=3.6 sal=2.7 sav=2.2 spi=1.1 sou=0.2 ric=2.8]
#   ✓  Mayonnaise                                true=rich      pred=rich      [swe=1.5 sal=1.6 sav=2.7 spi=0.5 sou=0.4 ric=3.2]
#   ✓  Ranch Dressing                            true=rich      pred=rich      [swe=0.2 sal=1.1 sav=3.1 spi=1.4 sou=0.8 ric=5.0]
#   ✓  Balsamic Vinaigrette                      true=rich      pred=rich      [swe=1.3 sal=1.9 sav=2.0 spi=1.4 sou=0.0 ric=2.1]
#   ✓  Lite Italian Dressing                     true=savory    pred=savory    [swe=1.2 sal=1.9 sav=3.1 spi=1.2 sou=0.8 ric=3.1]
#   ✓  Spicy Hummus Vinaigrette                  true=sour      pred=sour      [swe=0.7 sal=3.1 sav=3.6 spi=3.7 sou=4.2 ric=3.5]
#   ✓  Green Goddess Dressing                    true=rich      pred=rich      [swe=3.7 sal=4.4 sav=4.8 spi=3.1 sou=2.9 ric=5.0]
#   ✓  Dill Pickle Slices                        true=salty     pred=salty     [swe=0.0 sal=4.4 sav=3.3 spi=3.2 sou=2.5 ric=1.1]
#   ✓  Caramelized Onions                        true=savory    pred=savory    [swe=0.3 sal=1.5 sav=3.3 spi=0.5 sou=0.2 ric=1.6]
#   ✓  Black Beans                               true=savory    pred=savory    [swe=1.3 sal=1.6 sav=3.8 spi=0.1 sou=0.0 ric=1.4]
#   ✓  Shredded Cheddar Cheese                   true=rich      pred=rich      [swe=1.3 sal=2.3 sav=4.0 spi=1.2 sou=0.4 ric=5.0]
#   ✓  Fontana Cranberry-Pear Cobbler            true=salty     pred=salty     [swe=2.2 sal=4.3 sav=2.9 spi=0.9 sou=1.2 ric=4.3]
#   ✓  Pepper Jack Cheese                        true=rich      pred=rich      [swe=0.1 sal=2.1 sav=2.6 spi=1.9 sou=0.4 ric=5.0]
#   ✓  American Cheese                           true=rich      pred=rich      [swe=0.8 sal=2.2 sav=2.2 spi=1.0 sou=1.1 ric=4.3]
#   ✓  Provolone Cheese                          true=rich      pred=rich      [swe=0.1 sal=2.9 sav=2.2 spi=1.4 sou=0.5 ric=4.6]
#   ✓  Swiss Cheese                              true=rich      pred=rich      [swe=1.1 sal=2.3 sav=3.2 spi=1.4 sou=0.3 ric=4.5]
#   ✓  Chopped Hard-Cooked Egg                   true=rich      pred=rich      [swe=0.8 sal=1.9 sav=2.1 spi=1.2 sou=1.0 ric=3.3]
#   ✗  Chocolate Chip Coconut Bar                true=salty     pred=sweet     [swe=4.3 sal=4.6 sav=3.2 spi=0.8 sou=0.5 ric=4.4]
#
# --- Dinner ---
#   ✗  Garlic Herb Breadstick                    true=rich      pred=savory    [swe=1.0 sal=1.3 sav=4.8 spi=3.0 sou=0.6 ric=5.0]
#   ✓  Roasted Cauliflower                       true=salty     pred=salty     [swe=1.3 sal=3.7 sav=3.3 spi=3.6 sou=0.7 ric=3.6]
#   ✓  Asian Slaw                                true=savory    pred=savory    [swe=0.2 sal=2.9 sav=4.5 spi=3.6 sou=3.5 ric=2.1]
#   ✓  OH Pepperoni Pizza                        true=rich      pred=rich      [swe=3.8 sal=4.3 sav=3.6 spi=3.1 sou=0.9 ric=5.0]
#   ✓  OH Classic Cheese Pizza                   true=rich      pred=rich      [swe=3.0 sal=3.3 sav=4.0 spi=0.4 sou=1.5 ric=5.0]
#   ✓  Vegan Bar Sesame Soy Tofu                 true=savory    pred=savory    [swe=2.4 sal=4.4 sav=4.9 spi=2.7 sou=0.6 ric=3.6]
#   ✓  SHRIMP PRIMAVERA                          true=rich      pred=rich      [swe=0.4 sal=2.1 sav=3.7 spi=3.2 sou=2.6 ric=5.0]
#   ✓  Curried Chickpeas                         true=savory    pred=savory    [swe=0.7 sal=3.2 sav=4.7 spi=1.9 sou=0.3 ric=4.5]
#   ✓  Baked Penne Alfredo                       true=rich      pred=rich      [swe=1.3 sal=1.6 sav=2.6 spi=0.5 sou=0.4 ric=3.4]
#   ✓  Roasted Eggplant Mezze                    true=savory    pred=savory    [swe=2.1 sal=3.6 sav=5.0 spi=3.2 sou=2.7 ric=3.7]
#   ✗  Sesame Spinach                            true=rich      pred=salty     [swe=2.9 sal=3.2 sav=2.8 spi=0.7 sou=1.0 ric=3.8]
#   ✓  Green Beans Gremolada                     true=rich      pred=rich      [swe=1.0 sal=4.0 sav=3.1 spi=2.9 sou=3.1 ric=4.2]
#   ✓  Farro                                     true=salty     pred=salty     [swe=1.4 sal=3.0 sav=2.2 spi=0.9 sou=0.3 ric=3.0]
#   ✗  Kimchi Fried Rice                         true=rich      pred=savory    [swe=0.6 sal=1.2 sav=4.2 spi=3.6 sou=1.8 ric=5.0]
#   ✓  Lemon-Ginger Basmati Rice                 true=rich      pred=rich      [swe=0.7 sal=3.3 sav=4.0 spi=0.4 sou=3.9 ric=4.6]
#   ✓  Roasted Shawarma Chickpeas                true=savory    pred=savory    [swe=1.2 sal=3.6 sav=5.0 spi=1.7 sou=1.2 ric=4.3]
#   ✓  Boardwalk Tofu Wrap                       true=savory    pred=savory    [swe=0.9 sal=4.3 sav=5.0 spi=2.1 sou=3.5 ric=2.8]
#   ✓  Baja Turkey Wrap                          true=savory    pred=savory    [swe=3.3 sal=2.7 sav=4.8 spi=2.7 sou=2.2 ric=4.2]
#   ✓  Onion & Pepper Pizza                      true=rich      pred=rich      [swe=2.2 sal=3.9 sav=3.9 spi=3.5 sou=0.2 ric=4.4]
#   ✓  Fat-Free French Dressing                  true=rich      pred=rich      [swe=0.6 sal=2.2 sav=2.2 spi=0.1 sou=1.2 ric=2.4]
#   ✓  Dijon Mustard                             true=savory    pred=savory    [swe=0.4 sal=2.9 sav=4.0 spi=0.9 sou=1.0 ric=3.3]
#   ✓  Honey Mustard Dressing                    true=sweet     pred=sweet     [swe=3.6 sal=2.7 sav=2.2 spi=1.1 sou=0.2 ric=2.8]
#   ✓  Swiss Cheese                              true=rich      pred=rich      [swe=1.1 sal=2.3 sav=3.2 spi=1.4 sou=0.3 ric=4.5]
#   ✓  Provolone Cheese                          true=rich      pred=rich      [swe=0.1 sal=2.9 sav=2.2 spi=1.4 sou=0.5 ric=4.6]
#   ✓  American Cheese                           true=rich      pred=rich      [swe=0.8 sal=2.2 sav=2.2 spi=1.0 sou=1.1 ric=4.3]
#   ✓  Pepper Jack Cheese                        true=rich      pred=rich      [swe=0.1 sal=2.1 sav=2.6 spi=1.9 sou=0.4 ric=5.0]
#   ✓  Parmesan Cheese                           true=rich      pred=rich      [swe=1.5 sal=2.3 sav=2.8 spi=1.3 sou=0.5 ric=4.4]
#   ✓  Pork  Bulgogi                             true=savory    pred=savory    [swe=0.4 sal=1.1 sav=4.6 spi=3.3 sou=0.0 ric=3.1]
#   ✓  Chopped Fresh Spinach                     true=savory    pred=savory    [swe=0.1 sal=2.0 sav=2.6 spi=1.4 sou=0.8 ric=1.4]
#   ✓  Goldfish® Crackers                        true=savory    pred=savory    [swe=0.9 sal=2.8 sav=3.5 spi=0.3 sou=0.8 ric=3.0]
#   ✓  Croutons                                  true=savory    pred=savory    [swe=0.7 sal=1.1 sav=2.1 spi=0.7 sou=1.0 ric=1.2]
#   ✓  Baba Ghanoush                             true=savory    pred=savory    [swe=1.4 sal=4.1 sav=5.0 spi=3.2 sou=4.0 ric=3.3]
#   ✓  Meze Tzatziki Sauce                       true=savory    pred=savory    [swe=0.5 sal=3.5 sav=5.0 spi=3.0 sou=5.0 ric=5.0]
#   ✓  Sliced Red Onions                         true=rich      pred=rich      [swe=1.1 sal=1.3 sav=3.4 spi=0.8 sou=1.1 ric=3.5]
#   ✓  Feta Cheese Crumbles                      true=rich      pred=rich      [swe=0.2 sal=1.5 sav=3.0 spi=0.5 sou=0.7 ric=5.0]
#   ✓  Romaine Lettuce                           true=savory    pred=savory    [swe=0.7 sal=1.9 sav=3.5 spi=0.6 sou=0.8 ric=2.9]
#   ✓  Grape Tomatoes                            true=savory    pred=savory    [swe=0.6 sal=2.1 sav=3.9 spi=0.1 sou=0.0 ric=3.1]
#   ✓  Sliced Green Bell Peppers                 true=spicy     pred=spicy     [swe=0.3 sal=1.9 sav=3.2 spi=3.7 sou=1.0 ric=1.1]
#   ✓  Roasted Corn                              true=savory    pred=savory    [swe=0.1 sal=3.6 sav=4.0 spi=3.1 sou=0.7 ric=1.5]
#   ✓  Sliced Red Bell Peppers                   true=savory    pred=savory    [swe=0.1 sal=1.8 sav=3.3 spi=2.1 sou=1.2 ric=1.8]
#   ✓  Shredded Carrots                          true=savory    pred=savory    [swe=0.6 sal=1.1 sav=2.5 spi=1.3 sou=1.3 ric=1.3]
#   ✓  Spring Salad Mix                          true=salty     pred=salty     [swe=0.8 sal=2.6 sav=2.2 spi=1.4 sou=1.4 ric=1.4]
#   ✓  Sliced Cucumber                           true=rich      pred=rich      [swe=0.8 sal=2.3 sav=2.7 spi=1.2 sou=0.6 ric=3.3]
#   ✓  Chilled Roasted Mushrooms                 true=savory    pred=savory    [swe=1.1 sal=2.7 sav=4.8 spi=0.1 sou=0.7 ric=1.5]
#   ✓  Green Goddess Dressing                    true=rich      pred=rich      [swe=3.7 sal=4.4 sav=4.8 spi=3.1 sou=2.9 ric=5.0]
#   ✓  Spicy Hummus Vinaigrette                  true=sour      pred=sour      [swe=0.7 sal=3.1 sav=3.6 spi=3.7 sou=4.2 ric=3.5]
#   ✓  Lite Italian Dressing                     true=savory    pred=savory    [swe=1.2 sal=1.9 sav=3.1 spi=1.2 sou=0.8 ric=3.1]
#   ✓  Balsamic Vinaigrette                      true=rich      pred=rich      [swe=1.3 sal=1.9 sav=2.0 spi=1.4 sou=0.0 ric=2.1]
#   ✓  Ranch Dressing                            true=rich      pred=rich      [swe=0.2 sal=1.1 sav=3.1 spi=1.4 sou=0.8 ric=5.0]
#   ✓  Mayonnaise                                true=rich      pred=rich      [swe=1.5 sal=1.6 sav=2.7 spi=0.5 sou=0.4 ric=3.2]
#   ✓  Crushed Red Pepper                        true=spicy     pred=spicy     [swe=0.2 sal=2.5 sav=2.2 spi=3.6 sou=0.4 ric=2.0]
#   ✓  Black Beans                               true=savory    pred=savory    [swe=1.3 sal=1.6 sav=3.8 spi=0.1 sou=0.0 ric=1.4]
#   ✓  Chopped Hard-Cooked Egg                   true=rich      pred=rich      [swe=0.8 sal=1.9 sav=2.1 spi=1.2 sou=1.0 ric=3.3]
#   ✓  Shredded Cheddar Cheese                   true=rich      pred=rich      [swe=1.3 sal=2.3 sav=4.0 spi=1.2 sou=0.4 ric=5.0]
#   ✓  Corner Chicken Salad Croissant            true=rich      pred=rich      [swe=0.0 sal=2.8 sav=4.0 spi=2.7 sou=3.4 ric=4.6]
#   ✓  Cavalier Club                             true=salty     pred=salty     [swe=2.9 sal=5.0 sav=4.7 spi=3.8 sou=2.7 ric=3.2]
#   ✓  Meze Tomato Cucumber Salad                true=savory    pred=savory    [swe=1.0 sal=3.9 sav=4.7 spi=3.4 sou=3.0 ric=2.5]
#   ✓  Ginger Garlic Broccoli                    true=savory    pred=savory    [swe=0.5 sal=3.0 sav=5.0 spi=2.0 sou=0.7 ric=4.4]
#   ✓  Shredded Chicken with Chermoula Sauce     true=rich      pred=rich      [swe=0.7 sal=2.6 sav=4.0 spi=2.8 sou=4.2 ric=5.0]
#   ✓  Grilled Italian Vinaigrette Chicken Thigh  true=rich      pred=rich      [swe=2.6 sal=3.2 sav=3.2 spi=2.3 sou=2.9 ric=4.6]
#
# Day accuracy: 164/169 (97.0%)

# %% [markdown]
# ## 11. Feature Importance
#
# Permutation-based importance: for each feature, shuffle its column in the
# validation set and measure how much accuracy drops. A larger drop means that
# feature is more important.

# %%
np.random.seed(RANDOM_SEED)
baseline_acc = accuracy_score(y_val, best_model.predict(X_val))
importances = {}

for i, feat in enumerate(FEATURE_COLUMNS):
    X_val_perm = X_val.copy()
    np.random.shuffle(X_val_perm[:, i])
    perm_acc = accuracy_score(y_val, best_model.predict(X_val_perm))
    importances[feat] = baseline_acc - perm_acc

# Sort and plot
imp_sorted = dict(sorted(importances.items(), key=lambda x: x[1]))

fig, ax = plt.subplots(figsize=(8, 4))
colors_imp = [colors.get(f, "#888") for f in imp_sorted.keys()]
ax.barh(list(imp_sorted.keys()), list(imp_sorted.values()), color=colors_imp,
        edgecolor="black", linewidth=0.5)
ax.set_xlabel("Accuracy Drop When Shuffled")
ax.set_title("Feature Importance (Permutation-based)")
ax.axvline(x=0, color="black", linewidth=0.5)
for i, (feat, val) in enumerate(imp_sorted.items()):
    ax.text(val + 0.005, i, f"{val:+.4f}", va="center", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Summary

# %%
p_name = p_names.get(best_params["p"], f"Minkowski p={best_params['p']}")

summary = {
    "Classification Target": f"Dominant flavor ({', '.join(FEATURE_COLUMNS)})",
    "Best k (n_neighbors)": best_params["n_neighbors"],
    "Best weights": best_params["weights"],
    "Best distance metric": p_name,
    "Best scaler": best_params["scaler"],
    "Training samples": len(df_train),
    "Validation samples": len(df_val),
    "Test samples (day)": f"{len(df_test)} (date: {df_test['date'].iloc[0]})",
    "Training accuracy": f"{train_acc:.4f} ({train_acc*100:.1f}%)",
    "Validation accuracy": f"{val_acc:.4f} ({val_acc*100:.1f}%)",
    "Test accuracy": f"{test_acc:.4f} ({test_acc*100:.1f}%)",
}

for key, val in summary.items():
    print(f"  {key + ':':30s} {val}")

print(f"\nOutput files saved to '{OUTPUT_DIR}/':")
for f in sorted(os.listdir(OUTPUT_DIR)):
    size = os.path.getsize(os.path.join(OUTPUT_DIR, f))
    print(f"  {f:35s} {size/1024:.1f} KB")
# Out:
#   Classification Target:         Dominant flavor (sweet, salty, savory, spicy, sour, rich)
#   Best k (n_neighbors):          1
#   Best weights:                  uniform
#   Best distance metric:          Euclidean
#   Best scaler:                   standard
#   Training samples:              1257
#   Validation samples:            251
#   Test samples (day):            169 (date: 4-02-2026)
#   Training accuracy:             1.0000 (100.0%)
#   Validation accuracy:           0.9721 (97.2%)
#   Test accuracy:                 0.9704 (97.0%)
#
# Output files saved to './ondemand/':
#   all_items_combined.csv              560.9 KB
#   data                                4.0 KB
#   knn_model.pkl                       147.0 KB
#   scaler.pkl                          0.7 KB
#   test_split.csv                      56.1 KB
#   train_split.csv                     436.0 KB
#   validation_split.csv                78.9 KB

# %% [markdown]
# ## 13. Export

# %%
joblib.dump(best_model,  os.path.join(OUTPUT_DIR, "knn_model.pkl"))
joblib.dump(best_scaler, os.path.join(OUTPUT_DIR, "scaler.pkl"))

print(f"Saved model  → {os.path.join(OUTPUT_DIR, 'knn_model.pkl')}")
print(f"Saved scaler → {os.path.join(OUTPUT_DIR, 'scaler.pkl')}")
# Out:
# Saved model  → ./ondemand/knn_model.pkl
# Saved scaler → ./ondemand/scaler.pkl

# %% [markdown]
# ## 14. Load and Recommending Functions

# %%
# Load saved model and scaler
knn_model  = joblib.load(os.path.join(OUTPUT_DIR, "knn_model.pkl"))
knn_scaler = joblib.load(os.path.join(OUTPUT_DIR, "scaler.pkl"))

# Load the full item pool (built during training)
item_pool = pd.read_csv(os.path.join(OUTPUT_DIR, "all_items_combined.csv"))

# Drop any rows missing flavor scores
item_pool = item_pool.dropna(subset=FEATURE_COLUMNS).reset_index(drop=True)

print(f"Item pool loaded: {len(item_pool)} items")
print(f"Dates available: {sorted(item_pool['date'].unique())}")
print(f"Meals available: {sorted(item_pool['meal'].unique())}")
# Out:
# Item pool loaded: 1677 items
# Dates available: ['3-30-2026', '3-31-2026', '4-01-2026', '4-02-2026', '4-03-2026', '4-04-2026', '4-05-2026', '4-06-2026', '4-07-2026', '4-08-2026']
# Meals available: ['Breakfast', 'Dinner', 'Lunch']

# %%
def build_user_profile(history: list[dict]) -> np.ndarray:
    """
    Collapse a list of eaten meals into a single 6D flavor vector.
    Uses a simple mean; every eaten item contributes equally.
    Returns a zero vector if history is empty.
    """
    if not history:
        return np.zeros(len(FEATURE_COLUMNS))
    scores = np.array([[item[f] for f in FEATURE_COLUMNS] for item in history])
    return scores.mean(axis=0)

# %%
def get_candidates(
    pool: pd.DataFrame,
    user_history: list[dict],
    date: str = None,
    meal: str = None,
    categories=None,
) -> pd.DataFrame:
    """
    Filter the item pool to items the user hasn't eaten yet.

    date  — if provided, restrict to that date's menu
    meal  — if provided, restrict to that meal (Breakfast/Lunch/Dinner)
    """
    candidates = pool.copy()

    if date is not None:
        candidates = candidates[candidates["date"] == date]
    if meal is not None:
        candidates = candidates[candidates["meal"] == meal]
    if include_categories is not None:
        candidates = candidates[
            candidates["category"].isin(include_categories)
        ]

    # Exclude items already in the user's history
    eaten_names = {item["name"] for item in user_history}
    candidates = candidates[~candidates[ITEM_NAME_COLUMN].isin(eaten_names)]

    return candidates.reset_index(drop=True)

# %%
def recommend(
    candidates: pd.DataFrame,
    target_vector: np.ndarray,
    scaler,
    model,
    n: int = 5,
) -> pd.DataFrame:
    """
    Rank candidate items by flavor distance to the target vector.
    Returns the top-n closest items with distance, predicted label, and scores.
    """
    if candidates.empty:
        print("No candidates available.")
        return pd.DataFrame()

    X_candidates = candidates[FEATURE_COLUMNS].values.astype(float)

    # Scale using the same scaler fit during training
    if scaler is not None:
        X_scaled    = scaler.transform(X_candidates)
        target_scaled = scaler.transform([target_vector])[0]
    else:
        X_scaled      = X_candidates
        target_scaled = target_vector

    # Euclidean distance from each candidate to the target
    distances = np.linalg.norm(X_scaled - target_scaled, axis=1)

    # Attach distance and predicted dominant flavor label
    results = candidates.copy()
    results["distance"]         = distances
    results["predicted_flavor"] = model.predict(X_scaled)

    return (
        results
        .sort_values("distance")
        .head(n)
        .reset_index(drop=True)
    )

# %%
def record_meal(user_history: list[dict], item_row: pd.Series) -> list[dict]:
    """Add an eaten item to the user's session history."""
    user_history.append({
        "name": item_row[ITEM_NAME_COLUMN],
        "date": item_row["date"],
        "meal": item_row["meal"],
        **{f: item_row[f] for f in FEATURE_COLUMNS},
    })
    return user_history


def print_recommendations(recs: pd.DataFrame, target_vector: np.ndarray):
    """Pretty-print the recommendation list."""
    profile_str = "  ".join(
        f"{f[:3]}={v:.2f}" for f, v in zip(FEATURE_COLUMNS, target_vector)
    )
    print(f"  {'#':<3}  {'Item':<40}  {'Pred Flavor':<12}  {'Dist':>6}  Scores")
    print("  " + "─" * 85)
    for i, row in recs.iterrows():
        scores = "  ".join(f"{f[:3]}={row[f]:.1f}" for f in FEATURE_COLUMNS)
        print(
            f"  {i+1:<3}  {str(row[ITEM_NAME_COLUMN]):<40}  "
            f"{str(row['predicted_flavor']):<12}  {row['distance']:>6.3f}  [{scores}]"
        )


def print_profile(user_history: list[dict], user_profile: np.ndarray):
    """Print the user's current flavor profile."""
    if not user_history:
        print("No meals eaten yet.")
        return
    print(f"\nEaten so far ({len(user_history)} items):")
    for item in user_history:
        scores = "  ".join(f"{f[:3]}={item[f]:.1f}" for f in FEATURE_COLUMNS)
        print(f"  - {item['name']:<40} [{scores}]")
    profile_str = "  ".join(f"{f[:3]}={v:.3f}" for f, v in zip(FEATURE_COLUMNS, user_profile))
    print(f"\n  Your flavor profile → [{profile_str}]")

# %% [markdown]
# ## 15. Run!

# %%
# Configuration
SESSION_DATE = sorted(item_pool["date"].unique())[-1]  # most recent date in pool
SESSION_MEAL = "Lunch"                                  # change as needed
TOP_N        = 5

# Start fresh session
user_history = []

# Simulate: user has already eaten these items this morning
# Replace with real eaten item names, or leave empty to start clean
already_eaten_names = []  

for name in already_eaten_names:
    match = item_pool[item_pool[ITEM_NAME_COLUMN] == name]
    if not match.empty:
        user_history = record_meal(user_history, match.iloc[0])
    else:
        print(f"  Warning: '{name}' not found in item pool — skipping.")

# Build profile & get recommendations
include_categories = [
    'Omelet/Quiche/Frittata/Strata',
    'Breakfast',
    'Breakfast Meat',
    'Potato',
    'Pancakes/Waffles/French Toast',
    'Biscuit',
    'Traditional 16"',
    'Burger',
    'Traditional Sandwich',
    'Artisan',
    'Club',
    'Salad Entrée',
    'Roast/Braise',
    'Stir-Fry',
    'Casserole',
    'Burrito/Chimichanga',
    'Taco',
    'Hot Dog/Corn Dog',
    'Cream/Bisque/Puree',
    'BEEF ENTREE',
    'POULTRY ENTREE',
    'Pasta/Noodle (Entree)',
    'Rice',
    'Grains',
    'RICE/GRAINS/LEGUMES',
    'Grilled'
]
user_profile = build_user_profile(user_history)
target       = user_profile
candidates   = get_candidates(item_pool, user_history, date=SESSION_DATE, meal=SESSION_MEAL, categories=include_categories)
recs         = recommend(candidates, target, knn_scaler, knn_model, n=TOP_N)

print_profile(user_history, user_profile)
print_recommendations(recs, target)
# Out:
# No meals eaten yet.
#   #    Item                                      Pred Flavor     Dist  Scores
#   ─────────────────────────────────────────────────────────────────────────────────────
#   1    Char-Grilled Turkey Burger                savory         4.174  [swe=0.3  sal=1.2  sav=3.6  spi=0.3  sou=1.1  ric=1.5]
#   2    Grilled Black Bean Burger                 savory         4.490  [swe=0.1  sal=1.1  sav=3.7  spi=1.2  sou=1.2  ric=2.0]
#   3    Crispy Seasoned French Fries              rich           5.062  [swe=1.0  sal=2.5  sav=3.3  spi=1.4  sou=0.4  ric=3.4]
#   4    Tuna Salad Sandwich                       savory         5.877  [swe=1.3  sal=3.0  sav=3.7  spi=2.5  sou=2.6  ric=1.6]
#   5    Chicken Shawarma                          rich           6.400  [swe=0.2  sal=3.4  sav=3.0  spi=2.4  sou=3.3  ric=3.9]

# %%
# Pick one of the recommendations above and record it
# Set this to the index (0-based) of the item the user chose from the list above
CHOSEN_INDEX = 5
ITEM = "Chicken Shawarma"

if (CHOSEN_INDEX == 5):
    chosen_item = candidates.loc[candidates["name"] == ITEM].iloc[0]
else:
    chosen_item  = recs.iloc[CHOSEN_INDEX]
user_history = record_meal(user_history, chosen_item)

print(f"Recorded: {chosen_item[ITEM_NAME_COLUMN]}")

# Re-run with updated profile
user_profile = build_user_profile(user_history)
target       = user_profile
candidates   = get_candidates(item_pool, user_history, date=SESSION_DATE, meal=SESSION_MEAL, categories=include_categories)
recs         = recommend(candidates, target, knn_scaler, knn_model, n=TOP_N)

print_profile(user_history, user_profile)
print_recommendations(recs, target)
# Out:
# Recorded: Chicken Shawarma
#
# Eaten so far (2 items):
#   - Tuna Salad Sandwich                      [swe=1.3  sal=3.0  sav=3.7  spi=2.5  sou=2.6  ric=1.6]
#   - Chicken Shawarma                         [swe=0.2  sal=3.4  sav=3.0  spi=2.4  sou=3.3  ric=3.9]
#
#   Your flavor profile → [swe=0.750  sal=3.200  sav=3.350  spi=2.450  sou=2.950  ric=2.750]
#   #    Item                                      Pred Flavor     Dist  Scores
#   ─────────────────────────────────────────────────────────────────────────────────────
#   1    Corner Chicken Salad Croissant            rich           1.788  [swe=0.0  sal=2.8  sav=4.0  spi=2.7  sou=3.4  ric=4.6]
#   2    Boardwalk Tofu Wrap                       savory         2.054  [swe=0.9  sal=4.3  sav=5.0  spi=2.1  sou=3.5  ric=2.8]
#   3    Lemon-Ginger Basmati Rice                 rich           2.504  [swe=0.7  sal=3.3  sav=4.0  spi=0.4  sou=3.9  ric=4.6]
#   4    Crispy Seasoned French Fries              rich           2.623  [swe=1.0  sal=2.5  sav=3.3  spi=1.4  sou=0.4  ric=3.4]
#   5    Mojo Pork & Plantains Plate               savory         2.790  [swe=0.2  sal=4.2  sav=5.0  spi=2.9  sou=3.9  ric=5.0]
